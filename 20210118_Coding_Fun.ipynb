# %%
import pandas as pd

# %%
apple=pd.read_csv('D:\_Umesh WIP folder\_EDU HBY\___Coding Fun\AppleFinancials2.csv',skiprows=3,
                  index_col='in_million_USD')
apple_incom_st = apple.iloc[:9,1:]

# %%
listofyears = apple_incom_st.columns

# %%
for year in listofyears:
    apple_incom_st[year] = apple_incom_st[year].str.replace(",","")
    apple_incom_st[year] = apple_incom_st[year].astype(int)
apple_incom_st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, Revenue to Net Income Available to Common Shareholders
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FY '11  9 non-null      int32
#  1   FY '12  9 non-null      int32
#  2   FY '13  9 non-null      int32
#  3   FY '14  9 non-null      int32
#  4   FY '15  9 non-null      int32
#  5   FY '16  9 non-null      int32
#  6   FY '17  9 non-null      int32
#  7   FY '18  9 non-null      int32
#  8   FY '19  9 non-null      int32
#  9   FY '20  9 non-null      int32
# dtypes: int32(10)
# memory usage: 432.0+ bytes

# %%
import regex as re

# %%
apple_incom_st
# Out:
#                                              FY '11  FY '12  FY '13  FY '14  \
# in_million_USD
# Revenue                                      108249  156508  170910  182795
# Cost of revenue                              -64431  -87846 -106606 -112258
# Gross Profit                                  43818   68662   64304   70537
# Operating Expenses                           -10028  -13421  -15305  -18034
# Operating Income (Loss)                       33790   55241   48999   52503
# Non-Operating Income (Loss)                     415     522    1156     980
# Pretax Income (Loss)                          34205   55763   50155   53483
# Income Tax (Expense) Benefit, net             -8283  -14030  -13118  -13973
# Net Income Available to Common Shareholders   25922   41733   37037   39510
#
#                                              FY '15  FY '16  FY '17  FY '18  \
# in_million_USD
# Revenue                                      233715  215639  229234  265595
# ...

# %%
apple_incom_st[apple_incom_st['in_million_USD'].str.contains('Revenue',regex=False)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'in_million_USD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-19ad613a7e3e> in <module>
# ...
